# %% [markdown]
# # Pandas Hands On

# %%
import pandas as pd

# %% [markdown]
# `import <package_name> as <alias_name>`

# %% [markdown]
# ### Basic file formats
# 1. CSV file
# 2. Text File
# 3. JSON
# 4. Parquet
# 5. Pickle

# %%
adult_dataset=pd.read_csv('adult.data')

# %% [markdown]
# ### Display first few records of Dataset

# %%
adult_dataset.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %% [markdown]
# ### Display last few records of Dataset

# %%
adult_dataset.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# ...

# %% [markdown]
# ### Find out the total no.of records in the dataset

# %%
len(adult_dataset)
# Out:
# 32560

# %%
# shape - represents the dimensionality
adult_dataset.shape[0]
# Out:
# 32560

# %% [markdown]
# ### No.of columns in the dataset

# %%
adult_dataset.shape[1]
# Out:
# 15

# %%
cols=['age','workclass','fnlwgt','education','edu_num','marital_status','occupation','relation','race','gender','capital_gain','capital_loss','hours_per_week','country','income']

# %%
adult_dataset.columns=cols

# %%
adult_dataset.head()
# Out:
#    age          workclass  fnlwgt   education  edu_num       marital_status  \
# 0   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 1   38            Private  215646     HS-grad        9             Divorced
# 2   53            Private  234721        11th        7   Married-civ-spouse
# 3   28            Private  338409   Bachelors       13   Married-civ-spouse
# 4   37            Private  284582     Masters       14   Married-civ-spouse
#
#            occupation        relation    race   gender  capital_gain  \
# 0     Exec-managerial         Husband   White     Male             0
# 1   Handlers-cleaners   Not-in-family   White     Male             0
# 2   Handlers-cleaners         Husband   Black     Male             0
# 3      Prof-specialty            Wife   Black   Female             0
# 4     Exec-managerial            Wife   White   Female             0
#
#    capital_loss  hours_per_week         country  income
# ...

# %% [markdown]
# ### Exploratory Data Anlysis
# * Understand types of data in the data - Qualitative and Quantitaive features
# * Understand Descriptive Stats
# * Check if any if feature is having missing data
# * Visulaize the missing data
# * Nullity Correlation
# * Perform Data Imputation
# * Check the data distriubtion before and after performing data imputation
# * Check if the is in the normal distribution - plot and see
# * Transform the data to make it to follow normal / close to normal
# * Perform Feature Importance Analysis
#     * Feature Correlation
#     * Build a classifer / regressor

# %%
adult_dataset.describe(include='all')
# Out:
#                  age workclass        fnlwgt education       edu_num  \
# count   32560.000000     32560  3.256000e+04     32560  32560.000000
# unique           NaN         9           NaN        16           NaN
# top              NaN   Private           NaN   HS-grad           NaN
# freq             NaN     22696           NaN     10501           NaN
# mean       38.581634       NaN  1.897818e+05       NaN     10.080590
# std        13.640642       NaN  1.055498e+05       NaN      2.572709
# min        17.000000       NaN  1.228500e+04       NaN      1.000000
# 25%        28.000000       NaN  1.178315e+05       NaN      9.000000
# 50%        37.000000       NaN  1.783630e+05       NaN     10.000000
# 75%        48.000000       NaN  2.370545e+05       NaN     12.000000
# max        90.000000       NaN  1.484705e+06       NaN     16.000000
#
#              marital_status       occupation  relation    race gender  \
# ...

# %%
adult_dataset.age=adult_dataset.age.apply(lambda x: None if(x)>25  else x)

# %%
# import numpy
# import pandas as pd
# import logging
# import math
# import json

# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)


# def default_int_val(o):
#     if isinstance(o, numpy.int64): return int(o)
#     raise TypeError


# def percentage_to_quartile(stat):
#     if stat == '25':
#         return 'q1'
#     elif stat == '50':
#         return 'q2'
#     elif stat == '75':
#         return 'q3'
#     else:
#         return stat


# def get_feature_stats(df, dataset_name, feature, logging_function, tenant_name):
#     logging.info('getting the statistics of feature :  {}'.format(feature))
#     try:
#         if feature in df.columns:
#             stats = dict()
#             total_records = df.shape[0]
#             null_records = df[df[feature].isna()].shape[0]
#             stat_name = df[feature].describe().keys()
#             stat_name = [name.replace('%', '') for name in stat_name]
#             stat_name = [percentage_to_quartile(name) for name in stat_name]
#             stat_value = df[feature].describe().values
#             descriptive_stats = dict(zip(stat_name, stat_value))
#             stats['dataset_name'] = dataset_name
#             stats['feature_name'] = feature
#             stats['total_records'] = total_records
#             stats['null_records'] = null_records
#             stats['missing_percentage'] = null_records * 100 / total_records
#             stats['count'] = None
#             stats['mean'] = None
#             stats['std'] = None
#             stats['min'] = None
#             stats['q1'] = None
#             stats['q2'] = None
#             stats['q3'] = None
#             stats['max'] = None
#             stats['unique'] = None
#             stats['top'] = None
#             stats['freq'] = None
#             stats.update(descriptive_stats)
#             feature_stats = json.dumps(stats, default=default_int_val)
#             logging.info('successfully obtained the statistics of feature :  {}'.format(feature))
#             print(feature_stats)
#             logging_function(feature_stats, tenant_name)
#         else:
#             raise ValueError('feature ' + feature + ' is not available in the dataset {}'.format(dataset_name))
#     except Exception as e:
#         logging.error('Exception has occurred while getting the stats of {}'.format(feature))
#         logging.error(str(e))


# def get_merge_stats(left_df, left_df_name, right_df, right_df_name, left_on, right_on, how,logging_function,tenant_name,
#                     operation='join'):
#     logging.info('getting the merge statistics of data set :  {} and dataset: {}'.format(left_df_name,right_df_name))
#     left_df_stats = get_dataset_stats(left_df, left_df_name,None, logging_function, tenant_name)
#     logging_function(left_df_stats,tenant_name)
#     right_df_stats = get_dataset_stats(right_df, right_df_name, None, logging_function, tenant_name)
#     logging_function(right_df_stats,tenant_name)
#     merged_df = pd.merge(left=left_df, right=right_df, left_on=left_on, right_on=right_on, how=how)
#     dataset_name = left_df_name + ' ' + how + ' ' + operation + ' ' + right_df_name
#     operation = how + ' ' + operation
#     merge_stats = get_dataset_stats(merged_df, dataset_name, operation, logging_function, tenant_name)
#     logging_function(merge_stats,tenant_name)
#     logging.info('successfully obtained the merge statistics of dataset :  {} and dataset: {}'.format(left_df_name,
#                                                                                                       right_df_name))


# def get_dataset_stats(df, dataset_name, operation, logging_function, tenant_name):
#     logging.info('getting the statistics of dataset :  {}'.format(dataset_name))
#     dataset_size = df.shape[0]
#     qualitative_features = df.select_dtypes(include=['object', 'category']).columns.tolist()
#     quantitative_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
#     cols_with_missing_data = list(df.columns[df.isna().any()])
#     cols_with_complete_data = list(set(df.columns.tolist()) - set(cols_with_missing_data))
#     percent_missing = df.isnull().sum() * 100 / len(df)
#     missing_value_df = pd.DataFrame({'column_name': df.columns,
#                                      'percent_missing': percent_missing})
#     missing_value_df = missing_value_df.sort_values('percent_missing', ascending=False)
#     missing_value_df = missing_value_df[missing_value_df.percent_missing > 0]
#     percentage_missing = dict()
#     for ind, row in missing_value_df.iterrows():
#         percentage_missing[row['column_name']] = row['percent_missing']
#     df = df.drop_duplicates()
#     size_after_droping_duplicates = df.shape[0]
#     stats = df.describe()
#     stats_features = stats.keys().tolist()
#     stat_name = stats.T.keys().tolist()
#     stat_name = [name.replace('%', '') for name in stat_name]
#     stat_name = [percentage_to_quartile(stat) for stat in stat_name]
#     stat_value = stats.T.values
#     stat_value_updated = []
#     for i in range(len(stat_value)):
#         stat_value_updated.append([None if math.isnan(elem) else elem for elem in stat_value[i].tolist()])
#     descriptive_stats = dict()
#     for i in range(len(stats_features)):
#         descriptive_stats[stats_features[i]] = dict(zip(stat_name, stat_value_updated[i]))
#     formatted_log = {'dataset_name': dataset_name, 'operation': operation, 'no_of_records': dataset_size,
#                      'no_of_duplicate_records': dataset_size - size_after_droping_duplicates,
#                      'no_of_features': len(df.columns), 'no_of_qualitative_features': len(qualitative_features),
#                      'no_of_quantitative_features': len(quantitative_features),
#                      'no_of_features_with_missing_data': len(cols_with_missing_data),
#                      'no_of_features_with_complete_data': len(cols_with_complete_data),
#                      'list_of_qualitative_features': qualitative_features,
#                      'list_of_quantitative_features': quantitative_features,
#                      'list_of_features_with_missing_data': cols_with_missing_data,
#                      'list_of_features_with_complete_data': cols_with_complete_data,
#                      'percentage_missing_of_features': percentage_missing
#         , "qualitative_features": qualitative_features, "quantitative_features": quantitative_features,
#                      'descriptive_stats': descriptive_stats}
#     dataset_stats = json.dumps(formatted_log)
#     logging.info('successfully obtained the statistics of dataset :  {}'.format(dataset_name))
#     logging_function(dataset_stats, tenant_name)
#     logging.info('successfully logged the statistics of {} dataset to eventing db'.format(dataset_name))

# %%
# get_dataset_stats(adult_dataset,'adult_dataset',None,logging.info,'test')

# %%
import missingno as msno

# %%
adult_dataset.age.value_counts(dropna=False)
# Out:
# NaN      26149
#  23.0      877
#  25.0      841
#  24.0      798
#  22.0      765
#  20.0      753
#  21.0      720
#  19.0      712
#  18.0      550
#  17.0      395
# Name: age, dtype: int64

# %%
msno.matrix(adult_dataset)
