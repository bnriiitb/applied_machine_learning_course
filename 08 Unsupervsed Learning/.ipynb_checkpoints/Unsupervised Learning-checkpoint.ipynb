# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## Transformations

# %% [markdown]
# ### Standard Deviation
#
# <img src="std.PNG" width="1020">

# %% [markdown]
# ### Standard Scaler
# #### z = (x-u)/s

# %%
import pandas as pd
df = pd.DataFrame({'age':[21,22,12,1,2,3,4,6,33,45,23,4,23,42,34,33,4,3,5,3,37,7,85,4,56,3,45,75],
             'income':[234,4,35,54,5343,443,2344,244,125,7,7,456,54,34,75,7,55,745,867,765,756,77,477,866,686,675,998,902]})
df.head()
# Out:
#    age  income
# 0   21     234
# 1   22       4
# 2   12      35
# 3    1      54
# 4    2    5343

# %%
import seaborn as sns

# %% [markdown]
# ### Age Column Data Distribution

# %%
sns.distplot(df.age,hist=False)

# %% [markdown]
# ### Income Column Data Distribution

# %%
sns.distplot(df.income,hist=False)

# %% [markdown]
# ### Standard Scalar
# 1. Mean
# 2. Standard Deviation

# %%
import numpy as np
def mean(X):
    return np.sum(X)/len(X)

# %%
age_mean = mean(df.age.tolist())

# %% [markdown]
# <img src="std.PNG">

# %% [markdown]
# class StandardScalar():
#     def fit(X):
#         compute mean and standard deviation assing to self
#     def tansform(X):
#         returns (x-u)/s

# %%
def standard_deviation(X,u):
    return np.sqrt(np.sum(np.array([(x-u)**2 for x in X])/len(X)))

# %%
standard_deviation(df.age.tolist(),age_mean)
# Out:
# 22.712572936322186

# %%
age_mean
# Out:
# 22.678571428571427

# %%
s = df.age.std()
u = df.age.mean()

# %%
z = (x-u)/s

# %%
sns.distplot(df.age,hist=False)

# %%
sns.distplot([(x-u)/s for x in df.age],hist=False)

# %%
df.head()
# Out:
#    age  income
# 0   21     234
# 1   22       4
# 2   12      35
# 3    1      54
# 4    2    5343

# %%
from sklearn.preprocessing import RobustScaler

# %%
sns.distplot(df.age)

# %%
sns.distplot(df.income)

# %%
import numpy as np
rs = RobustScaler()
sns.distplot(rs.fit_transform(np.array(df.income).reshape(-1,1)))

# %%
sns.distplot(rs.fit_transform(np.array(df.age).reshape(-1,1)))

# %%
# rs.fit_transform(np.array(df.age).reshape(-1,1))

# %%
Standard Scalar = Mean, Std
Robust Scalar = Median, IQR
MinMax Scalar = Min, Range
Normalizer = , 

L1 - abs(x)
L2 -

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()

# %%
a = 2
a = [1,2,3,4,5]
b= [1,2]

a.b = [1x1,2x2]
TF-IDF - Term Frequency - Inverse Document Frequency [.13,0.32]

# %%
df.age
# Out:
# 0     21
# 1     22
# 2     12
# 3      1
# 4      2
# 5      3
# 6      4
# 7      6
# 8     33
# 9     45
# 10    23
# 11     4
# 12    23
# 13    42
# 14    34
# 15    33
# 16     4
# 17     3
# 18     5
# 19     3
# 20    37
# 21     7
# 22    85
# 23     4
# 24    56
# 25     3
# 26    45
# 27    75
# Name: age, dtype: int64

# %%
from sklearn.preprocessing import Normalizer

# %%
X = [[22,3000,10],[24,40,160],[26,3000,10],[12,3000,70]]

# %%
n = Normalizer(norm='max')
# n.fit(np.array(df.age).reshape(-1,1))
# n.transform(np.array(df.age).reshape(-1,1))
n.fit_transform(X)
# Out:
# array([[0.00733333, 1.        , 0.00333333],
#        [0.006     , 1.        , 0.004     ],
#        [0.00866667, 1.        , 0.00333333],
#        [0.004     , 1.        , 0.02333333]])

# %%
df.age/df.age.sum()
# Out:
# 0     0.033071
# 1     0.034646
# 2     0.018898
# 3     0.001575
# 4     0.003150
# 5     0.004724
# 6     0.006299
# 7     0.009449
# 8     0.051969
# 9     0.070866
# 10    0.036220
# 11    0.006299
# 12    0.036220
# 13    0.066142
# 14    0.053543
# 15    0.051969
# 16    0.006299
# 17    0.004724
# 18    0.007874
# 19    0.004724
# 20    0.058268
# 21    0.011024
# 22    0.133858
# 23    0.006299
# 24    0.088189
# 25    0.004724
# 26    0.070866
# 27    0.118110
# Name: age, dtype: float64
